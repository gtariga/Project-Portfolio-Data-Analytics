# %% [markdown]
# # **TikTok Project**
# **Course 6 - The Nuts and bolts of machine learning**

# %% [markdown]
# Recall that you are a data professional at TikTok. Your supervisor was impressed with the work you have done and has requested that you build a machine learning model that can be used to determine whether a video contains a claim or whether it offers an opinion. With a successful prediction model, TikTok can reduce the backlog of user reports and prioritize them more efficiently.
#
# A notebook was structured and prepared to help you in this project. A notebook was structured and prepared to help you in this project. Please complete the following questions.

# %% [markdown]
# # **Course 6 End-of-course project: Classifying videos using machine learning**
#
# In this activity, you will practice using machine learning techniques to predict on a binary outcome variable.
# <br/>
#
# **The purpose** of this model is to increase response time and system efficiency by automating the initial stages of the claims process.
#
# **The goal** of this model is to predict whether a TikTok video presents a "claim" or presents an "opinion".
# <br/>
#
# *This activity has three parts:*
#
# **Part 1:** Ethical considerations
# * Consider the ethical implications of the request
#
# * Should the objective of the model be adjusted?
#
# **Part 2:** Feature engineering
#
# * Perform feature selection, extraction, and transformation to prepare the data for modeling
#
# **Part 3:** Modeling
#
# * Build the models, evaluate them, and advise on next steps
#
# Follow the instructions and answer the questions below to complete the activity. Then, you will complete an Executive Summary using the questions listed on the PACE Strategy Document.
#
# Be sure to complete this activity before moving on. The next course item will provide you with a completed exemplar to compare to your own work.

# %% [markdown]
# # **Classify videos using machine learning**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## **PACE: Plan**
#
# Consider the questions in your PACE Strategy Document to reflect on the Plan stage.
#
# In this stage, consider the following questions:
#
#
# 1.   **What are you being asked to do? What metric should I use to evaluate success of my business/organizational objective?**
#
# 2.   **What are the ethical implications of the model? What are the consequences of your model making errors?**
#   *   What is the likely effect of the model when it predicts a false negative (i.e., when the model says a video does not contain a claim and it actually does)?
#
#   *   What is the likely effect of the model when it predicts a false positive (i.e., when the model says a video does contain a claim and it actually does not)?
#
# 3.   **How would you proceed?**

# %% [markdown]
# ==> ENTER YOUR RESPONSES HERE

# %% [markdown]
# ### **Task 1. Imports and data loading**
#
# Start by importing packages needed to build machine learning models to achieve the goal of this project.

# %%
# Import packages for data manipulation
### YOUR CODE HERE ###
import pandas as pd
import numpy as np

# Import packages for data visualization
### YOUR CODE HERE ###
import matplotlib.pyplot as plt
import seaborn as sns


# Import packages for data preprocessing
### YOUR CODE HERE ###


# Import packages for data modeling
### YOUR CODE HERE ###
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, precision_score, \
recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier
from xgboost import plot_importance

# %% [markdown]
# Now load the data from the provided csv file into a dataframe.
#
# **Note:** As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# Load dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## **PACE: Analyze**
#
# Consider the questions in your PACE Strategy Document to reflect on the Analyze stage.

# %% [markdown]
# ### **Task 2: Examine data, summary info, and descriptive stats**

# %% [markdown]
# Inspect the first five rows of the dataframe.

# %%
# Display first few rows
### YOUR CODE HERE ###
data.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %% [markdown]
# Get the number of rows and columns in the dataset.

# %%
# Get number of rows and columns
### YOUR CODE HERE ###
data.shape
# Out:
# (19382, 12)

# %% [markdown]
# Get the data types of the columns.

# %%
# Get data types of columns
### YOUR CODE HERE ###
data.dtypes
# Out:
# #                             int64
# claim_status                 object
# video_id                      int64
# video_duration_sec            int64
# video_transcription_text     object
# verified_status              object
# author_ban_status            object
# video_view_count            float64
# video_like_count            float64
# video_share_count           float64
# video_download_count        float64
# video_comment_count         float64
# dtype: object

# %% [markdown]
# Get basic information about the dataset.

# %%
# Get basic information
### YOUR CODE HERE ###
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# Generate basic descriptive statistics about the dataset.

# %%
# Generate basic descriptive stats
### YOUR CODE HERE ###
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# Check for and handle missing values.

# %%
# Check for missing values
### YOUR CODE HERE ###
data.isnull().sum()
# Out:
# #                             0
# claim_status                298
# video_id                      0
# video_duration_sec            0
# video_transcription_text    298
# verified_status               0
# author_ban_status             0
# video_view_count            298
# video_like_count            298
# video_share_count           298
# video_download_count        298
# video_comment_count         298
# dtype: int64

# %%
# Drop rows with missing values
### YOUR CODE HERE ###
data_subset = data.dropna(axis = 0)

# %%
# Display first few rows after handling missing values
### YOUR CODE HERE ###
data_subset.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %% [markdown]
# Check for and handle duplicates.

# %%
# Check for duplicates
### YOUR CODE HERE ###
data_subset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Check for and handle outliers.

# %%
### YOUR CODE HERE ###

#make boxplots for numerical values
num_var = ['video_duration_sec','video_view_count', 'video_share_count', 'video_like_count', 'video_download_count', 'video_comment_count']
fig, axs = plt.subplots(3,2, figsize = (10,8))
row = 0
for row in range(3):
    for col in range(2):
        sns.boxplot(data = data_subset[num_var[0]], ax = axs[row,col])
        axs[row][col].set_xlabel(num_var[0])
        axs[row][col].set_title('Boxplot for ' + num_var[0])
        num_var.pop(0)
plt.tight_layout()
plt.show()

#Random forest doesn't get affected by outliers so we do not need to deal with outliers

# %% [markdown]
# Check class balance.

# %%
# Check class balance
### YOUR CODE HERE ###
data_subset['claim_status'].value_counts(normalize=True)
# Out:
# claim_status
# claim      0.503458
# opinion    0.496542
# Name: proportion, dtype: float64

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
# Consider the questions in your PACE Strategy Document to reflect on the Construct stage.

# %% [markdown]
# ### **Task 3: Feature engineering**

# %% [markdown]
# Extract the length of each `video_transcription_text` and add this as a column to the dataframe, so that it can be used as a potential feature in the model.

# %%
# Extract the length of each `video_transcription_text` and add this as a column to the dataframe
### YOUR CODE HERE ###

#This will prompt a false positive warning when running. Meaning the warning doesn't apply to this code
data_subset['video_transcription_text_len'] = data_subset['video_transcription_text'].apply(lambda text: len(text))
# Out:
# /tmp/ipykernel_15228/1259215935.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset['video_transcription_text_len'] = data_subset['video_transcription_text'].apply(lambda text: len(text))

# %% [markdown]
# Calculate the average text_length for claims and opinions.

# %%
# Display first few rows of dataframe after adding new column
### YOUR CODE HERE ###
data_subset['video_transcription_text_len'].mean()
# Out:
# 89.09353385034584

# %% [markdown]
# Visualize the distribution of `video_transcription_text` length for claims and opinions.

# %%
# Visualize the distribution of `video_transcription_text` length for claims and opinions
# Create two histograms in one plot
### YOUR CODE HERE ###
fig, axs = plt.subplots(1,2, figsize = (10,2))
sns.histplot(data_subset[data_subset['claim_status']=='claim']['video_transcription_text_len'], ax = axs[0])
axs[0].set_xlabel('video transcription text length')
axs[0].set_ylabel('length value')
axs[0].set_title('Claim Video Transcription Text Length')
sns.histplot(data_subset[data_subset['claim_status']=='opinion']['video_transcription_text_len'], ax = axs[1])
axs[1].set_xlabel('video transcription text length')
axs[1].set_ylabel('length value')
axs[1].set_title('Opinion Video Transcription Text Length')
plt.tight_layout()
plt.show()

sns.histplot(data=data_subset, stat="count", multiple="dodge", x='video_transcription_text_len',
             kde=False, palette="pastel", hue="claim_status",
             element="bars", legend=True)
plt.xlabel("video_transcription_text length (number of characters)")
plt.ylabel("Count")
plt.title("Distribution of video_transcription_text length for claims and opinions")
plt.show()

# %% [markdown]
# Create a heatmap to visualize how correlated variables are. Consider which variables you're interested in examining correlations between.

# %%
# Create a heatmap to visualize how correlated variables are
### YOUR CODE HERE ###
data_subset_dummies = pd.get_dummies(data_subset, columns = ['claim_status','verified_status', 'author_ban_status'], drop_first = True)
data_subset_dummies = data_subset_dummies.drop('video_transcription_text', axis = 1)
data_subset_dummies.head()
sns.heatmap(data_subset_dummies.drop(['#','video_id'],axis=1).corr(), annot=True, fmt='.2f')
plt.title('Correlation Heat Map')
plt.show()

# %% [markdown]
# One of the model assumptions for logistic regression is no severe multicollinearity among the features. Take this into consideration as you examine the heatmap and choose which features to proceed with.

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
# Consider the questions in your PACE Strategy Document to reflect on the Construct stage.

# %% [markdown]
# ### **Task 3. Feature engineering**

# %% [markdown]
# Select the outcome variable.

# %%
# Select outcome variable
### YOUR CODE HERE ###
y = data_subset['claim_status']

# %% [markdown]
# **Feature selection and transformation**

# %% [markdown]
# Encode target and catgorical variables.

# %%
### YOUR CODE HERE ###

# Display first few rows
### YOUR CODE HERE ###
X = data_subset.copy()
#drop id and # because there aren't useful
X = X.drop(['video_id','#', 'video_transcription_text'], axis = 1)
#label encode claim status for target variable
X['claim_status'] = X['claim_status'].replace({'claim':1, 'opinion':0})
X = pd.get_dummies(X, columns = ['verified_status', 'author_ban_status'], drop_first = True)
X.head()
# Out:
#    claim_status  video_duration_sec  video_view_count  video_like_count  \
# 0             1                  59          343296.0           19425.0
# 1             1                  32          140877.0           77355.0
# 2             1                  31          902185.0           97690.0
# 3             1                  25          437506.0          239954.0
# 4             1                  19           56167.0           34987.0
#
#    video_share_count  video_download_count  video_comment_count  \
# 0              241.0                   1.0                  0.0
# 1            19034.0                1161.0                684.0
# 2             2858.0                 833.0                329.0
# 3            34812.0                1234.0                584.0
# 4             4110.0                 547.0                152.0
#
#    video_transcription_text_len  verified_status_verified  \
# 0                            97                     False
# ...

# %% [markdown]
# ### **Task 4. Split the data**

# %% [markdown]
# Assign target variable.

# %%
### YOUR CODE HERE ###
y = X['claim_status']

# %% [markdown]
# Isolate the features.

# %%
#Isolate features
### YOUR CODE HERE ###
X = X.drop('claim_status', axis = 1)
# Display first few rows of features dataframe
### YOUR CODE HERE ###
X.head()
# Out:
#    video_duration_sec  video_view_count  video_like_count  video_share_count  \
# 0                  59          343296.0           19425.0              241.0
# 1                  32          140877.0           77355.0            19034.0
# 2                  31          902185.0           97690.0             2858.0
# 3                  25          437506.0          239954.0            34812.0
# 4                  19           56167.0           34987.0             4110.0
#
#    video_download_count  video_comment_count  video_transcription_text_len  \
# 0                   1.0                  0.0                            97
# 1                1161.0                684.0                           107
# 2                 833.0                329.0                           137
# 3                1234.0                584.0                           131
# 4                 547.0                152.0                           128
#
# ...

# %% [markdown]
# #### **Task 5: Create train/validate/test sets**

# %% [markdown]
# Split data into training and testing sets, 80/20.

# %%
### YOUR CODE HERE ###
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %% [markdown]
# Split the training set into training and validation sets, 75/25, to result in a final ratio of 60/20/20 for train/validate/test sets.

# %%
### YOUR CODE HERE ###
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state = 0)

# %% [markdown]
# Confirm that the dimensions of the training, validation, and testing sets are in alignment.

# %%
### YOUR CODE HERE ###
print(X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape,)
# Out:
# (11450, 10) (3817, 10) (3817, 10) (11450,) (3817,) (3817,)

# %% [markdown]
# ### **Task 6. Build models**

# %% [markdown]
# ### **Build a random forest model**

# %% [markdown]
# Fit a random forest model to the training set. Use cross-validation to tune the hyperparameters and select the model that performs best on recall.

# %%
# Instantiate the random forest classifier
### YOUR CODE HERE ###
rf_clf = RandomForestClassifier(random_state=69)

# Create a dictionary of hyperparameters to tune
### YOUR CODE HERE ###
cv_params = {'max_depth': [5, 7, None],
             'max_features': [0.3, 0.6],
             'max_samples': [0.7],
             'min_samples_leaf': [1,2],
             'min_samples_split': [2,3],
             'n_estimators': [75,100,200],}

# Define a dictionary of scoring metrics to capture
### YOUR CODE HERE ###
scoring = {'accuracy', 'precision', 'f1', 'recall'}
# Instantiate the GridSearchCV object
### YOUR CODE HERE ###
rf_cv = GridSearchCV(rf_clf, cv_params, scoring=scoring, cv=5, refit='f1')

# %%
# %%time
# Examine best recall score
### YOUR CODE HERE ###

rf_cv.fit(X_train, y_train)
rf_cv.best_score_
# Out:
# CPU times: user 5min, sys: 466 ms, total: 5min
# Wall time: 5min
# 0.995230232382012

# %%
  # Get all the results from the CV and put them in a df
### YOUR CODE HERE ###
results = pd.DataFrame(columns=['Model', 'F1', 'Recall', 'Precision', 'Accuracy'])

def make_results(model_name, model_object):
    """
    Accepts as arguments a model name (your choice - string) and
    a fit GridSearchCV model object.

    Returns a pandas df with the F1, recall, precision, and accuracy scores
    for the model with the best mean F1 score across all validation folds.  
    """

    # Get all the results from the CV and put them in a df.
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(mean f1 score).
    best_estimator_results = cv_results.iloc[cv_results['mean_test_f1'].idxmax(), :]

    # Extract accuracy, precision, recall, and f1 score from that row.
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy

    # Create a table of results.
    table = pd.DataFrame()
    best = pd.DataFrame({'Model': model_name, 
                         'F1': f1, 
                         'Recall': recall, 
                         'Precision': precision, 
                         'Accuracy': accuracy},
                        index=[0])
    table = pd.concat([table,best], ignore_index=True)

    return table

result_table = make_results("Tuned Random Forest", rf_cv)

result_table
# Out:
#                  Model       F1    Recall  Precision  Accuracy
# 0  Tuned Random Forest  0.99523  0.991026   0.999479  0.995197

# %%
# Examine best parameters
### YOUR CODE HERE ###
rf_cv.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 0.6,
#  'max_samples': 0.7,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'n_estimators': 200}

# %% [markdown]
# **Question:** How well is your model performing? Consider average recall score and precision score.

# %% [markdown]
# ### **Build an XGBoost model**

# %%
# Instantiate the XGBoost classifier
xgb = XGBClassifier(objective='binary:logistic', random_state=0)

# Create a dictionary of hyperparameters to tune
cv_params = {'max_depth': [4,8,12],
             'min_child_weight': [3, 5],
             'learning_rate': [0.01, 0.1],
             'n_estimators': [300, 500]
             }

# Define a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# Instantiate the GridSearchCV object
xgb_cv = GridSearchCV(xgb, cv_params, scoring=scoring, cv=5, refit='recall')

xgb_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
  # Get all the results from the CV and put them in a df
### YOUR CODE HERE ###
results = pd.DataFrame(columns=['Model', 'F1', 'Recall', 'Precision', 'Accuracy'])

def make_results(model_name, model_object):
    """
    Accepts as arguments a model name (your choice - string) and
    a fit GridSearchCV model object.

    Returns a pandas df with the F1, recall, precision, and accuracy scores
    for the model with the best mean F1 score across all validation folds.  
    """

    # Get all the results from the CV and put them in a df.
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(mean f1 score).
    best_estimator_results = cv_results.iloc[cv_results['mean_test_f1'].idxmax(), :]

    # Extract accuracy, precision, recall, and f1 score from that row.
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy

    # Create a table of results.
    table = pd.DataFrame()
    best = pd.DataFrame({'Model': model_name, 
                         'F1': f1, 
                         'Recall': recall, 
                         'Precision': precision, 
                         'Accuracy': accuracy},
                        index=[0])
    table = pd.concat([table,best], ignore_index=True)

    return table

result_table = make_results("Tuned Random Forest", xgb_cv)

result_table
# Out:
#                  Model        F1    Recall  Precision  Accuracy
# 0  Tuned Random Forest  0.995142  0.990681   0.999652  0.995109

# %% [markdown]
# **Question:** How well does your model perform? Consider recall score and precision score.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
# Consider the questions in your PACE Strategy Document to reflect on the Execute stage.

# %% [markdown]
# ### **Task 7. Evaluate model**
#
# Evaluate models against validation criteria.

# %% [markdown]
# #### **Random forest**

# %%
# Use the random forest "best estimator" model to get predictions on the encoded testing set
### YOUR CODE HERE ###
y_pred = rf_cv.best_estimator_.predict(X_val)

# %% [markdown]
# Display the predictions on the encoded testing set.

# %%
# Display the predictions on the encoded testing set
### YOUR CODE HERE ###
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %% [markdown]
# Display the true labels of the testing set.

# %%
# Display the true labels of the testing set
### YOUR CODE HERE ###
y_test
# Out:
# 3695     1
# 11495    0
# 7604     1
# 12728    0
# 875      1
#         ..
# 5488     1
# 10842    0
# 16253    0
# 1933     1
# 15475    0
# Name: claim_status, Length: 3817, dtype: int64

# %% [markdown]
# Create a confusion matrix to visualize the results of the classification model.

# %%
# Create a confusion matrix to visualize the results of the classification model

# Compute values for confusion matrix
log_cm = confusion_matrix(y_val, y_pred)

# Create display of confusion matrix
log_disp = ConfusionMatrixDisplay(confusion_matrix=log_cm, display_labels=None)

# Plot confusion matrix
log_disp.plot()

# Display plot
plt.show()

# %% [markdown]
# Create a classification report that includes precision, recall, f1-score, and accuracy metrics to evaluate the performance of the model.

# %%
# Create a classification report
# Create classification report for random forest model
### YOUR CODE HERE ###
target_labels = ['opinion', 'claim']
print(classification_report(y_val, y_pred, target_names=target_labels))
# Out:
#               precision    recall  f1-score   support
#
#      opinion       0.99      1.00      0.99      1892
#        claim       1.00      0.99      0.99      1925
#
#     accuracy                           0.99      3817
#    macro avg       0.99      0.99      0.99      3817
# weighted avg       0.99      0.99      0.99      3817

# %% [markdown]
# **Question:** What does your classification report show? What does the confusion matrix indicate?

# %% [markdown]
# #### **XGBoost**

# %%
#Evaluate XGBoost model
### YOUR CODE HERE ###
y_pred = xgb_cv.best_estimator_.predict(X_val)

# %%
# Compute values for confusion matrix
log_cm = confusion_matrix(y_val, y_pred)

# Create display of confusion matrix
log_disp = ConfusionMatrixDisplay(confusion_matrix=log_cm, display_labels=None)

# Plot confusion matrix
log_disp.plot()

# Display plot
plt.title('XGBoost - validation set');
plt.show()

# %%
# Create a classification report
### YOUR CODE HERE ###
target_labels = ['opinion', 'claim']
print(classification_report(y_val, y_pred, target_names=target_labels))
# Out:
#               precision    recall  f1-score   support
#
#      opinion       0.99      1.00      0.99      1892
#        claim       1.00      0.99      0.99      1925
#
#     accuracy                           0.99      3817
#    macro avg       0.99      0.99      0.99      3817
# weighted avg       0.99      0.99      0.99      3817

# %% [markdown]
# **Question:** Describe your XGBoost model results. How does your XGBoost model compare to your random forest model?

# %% [markdown]
# ### **Use champion model to predict on test data**

# %%
### YOUR CODE HERE ###
y_pred = rf_cv.best_estimator_.predict(X_test)

# %%
# Compute values for confusion matrix
log_cm = confusion_matrix(y_test, y_pred)

# Create display of confusion matrix
log_disp = ConfusionMatrixDisplay(confusion_matrix=log_cm, display_labels=None)

# Plot confusion matrix
log_disp.plot()

# Display plot
plt.title('Random forest - test set');
plt.show()

# %% [markdown]
# #### **Feature importances of champion model**

# %%
### YOUR CODE HERE ###
importances = rf_cv.best_estimator_.feature_importances_
rf_importances = pd.Series(importances, index=X_test.columns)

fig, ax = plt.subplots()
rf_importances.plot.bar(ax=ax)
ax.set_title('Feature importances')
ax.set_ylabel('Mean decrease in impurity')
fig.tight_layout()

# %% [markdown]
# **Question:** Describe your most predictive features. Were your results surprising?

# %% [markdown]
# ### **Task 8. Conclusion**
#
# In this step use the results of the models above to formulate a conclusion. Consider the following questions:
#
# 1. *Would you recommend using this model? Why or why not?*
# Yes, one can recommend this model because it performed well on both the validation and test holdout data. Furthermore, both precision and F<sub>1</sub> scores were consistently high. The model very successfully classified claims and opinions.
# </br>
# 2. *What was your model doing? Can you explain how it was making predictions?*
# The model's most predictive features were all related to the user engagement levels associated with each video. It was classifying videos based on how many views, likes, shares, and downloads they received.
# </br>
# 3. *Are there new features that you can engineer that might improve model performance?*
# Because the model currently performs nearly perfectly, there is no need to engineer any new features.
# </br>
# 4. *What features would you want to have that would likely improve the performance of your model?*
# The current version of the model does not need any new features. However, it would be helpful to have the number of times the video was reported. It would also be useful to have the total number of user reports for all videos posted by each author.
#
# Remember, sometimes your data simply will not be predictive of your chosen target. This is common. Machine learning is a powerful tool, but it is not magic. If your data does not contain predictive signal, even the most complex algorithm will not be able to deliver consistent and accurate predictions. Do not be afraid to draw this conclusion.

# %% [markdown]
# ==> ENTER YOUR RESPONSES HERE
